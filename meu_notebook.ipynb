# %% [markdown]
# ## Dataset usado para treino nas aulas de Métodos Quantitativos - Venda de jogos

# %%
import kagglehub
import pandas as pd
# uma alternativa pra eu ver o nome do arquivo -> import os > print(os.listdir(path))

path = kagglehub.dataset_download("bhushandivekar/video-game-sales-and-industry-data-1980-2024") # aqui ele baixa uma pasta com os dados
df = pd.read_csv(path + "/Video_Games_Sales_Cleaned.csv")
df.head(25)
# Out:
# Using Colab cache for faster access to the 'video-game-sales-and-industry-data-1980-2024' dataset.
#                              title console             genre  \
# 0               Grand Theft Auto V     PS3            Action
# 1               Grand Theft Auto V     PS4            Action
# 2      Grand Theft Auto: Vice City     PS2            Action
# 3               Grand Theft Auto V    X360            Action
# 4        Call of Duty: Black Ops 3     PS4           Shooter
# 5   Call of Duty: Modern Warfare 3    X360           Shooter
# 6          Call of Duty: Black Ops    X360           Shooter
# 7            Red Dead Redemption 2     PS4  Action-Adventure
# 8       Call of Duty: Black Ops II    X360           Shooter
# 9       Call of Duty: Black Ops II     PS3           Shooter
# 10  Call of Duty: Modern Warfare 2    X360           Shooter
# 11              Call of Duty: WWII     PS4           Shooter
# 12  Call of Duty: Modern Warfare 3     PS3           Shooter
# ...

# %%
df["title"].nunique()
# Out:
# 12935

# %%
df["console"].unique()
# Out:
# array(['PS3', 'PS4', 'PS2', 'X360', 'XOne', 'PC', 'PSP', 'Wii', 'PS',
#        'DS', '2600', 'GBA', 'NES', 'XB', 'PSN', 'GEN', 'PSV', 'DC', 'N64',
#        'SAT', 'SNES', 'GBC', 'GC', 'NS', '3DS', 'GB', 'WiiU', 'WS', 'VC',
#        'NG', 'WW', 'SCD', 'PCE', 'XBL', '3DO', 'GG', 'OSX', 'Mob', 'PCFX'],
#       dtype=object)

# %%
df["total_sales"].head(10)
# Out:
# 0    20.32
# 1    19.39
# 2    16.15
# 3    15.86
# 4    15.09
# 5    14.82
# 6    14.74
# 7    13.94
# 8    13.86
# 9    13.80
# Name: total_sales, dtype: float64

# %%
df["title"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18832 entries, 0 to 18831
# Series name: title
# Non-Null Count  Dtype
# --------------  -----
# 18832 non-null  object
# dtypes: object(1)
# memory usage: 147.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18832 entries, 0 to 18831
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         18832 non-null  object
#  1   console       18832 non-null  object
#  2   genre         18832 non-null  object
#  3   publisher     18832 non-null  object
#  4   developer     18832 non-null  object
#  5   critic_score  18832 non-null  float64
#  6   total_sales   18832 non-null  float64
#  7   release_year  18832 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 1.1+ MB

# %%
df[['title', 'console', 'total_sales']]
# Out:
#                                              title console  total_sales
# 0                               Grand Theft Auto V     PS3        20.32
# 1                               Grand Theft Auto V     PS4        19.39
# 2                      Grand Theft Auto: Vice City     PS2        16.15
# 3                               Grand Theft Auto V    X360        15.86
# 4                        Call of Duty: Black Ops 3     PS4        15.09
# ...                                            ...     ...          ...
# 18827                                    Teslagrad    WiiU         0.00
# 18828                                  Open Season      XB         0.00
# 18829              The SpongeBob SquarePants Movie      PC         0.00
# 18830                  Santa Claus Saves the Earth     GBA         0.00
# 18831  Fossil League: Dino Tournament Championship      DS         0.00
#
# [18832 rows x 3 columns]

# %% [markdown]
# - **query()**: Usado para filtrar DataFrames usando expressões booleanas baseadas em strings

# %%
df.query("console=='X360'")
# Out:
#                                             title console         genre  \
# 3                              Grand Theft Auto V    X360        Action
# 5                  Call of Duty: Modern Warfare 3    X360       Shooter
# 6                         Call of Duty: Black Ops    X360       Shooter
# 8                      Call of Duty: Black Ops II    X360       Shooter
# 10                 Call of Duty: Modern Warfare 2    X360       Shooter
# ...                                           ...     ...           ...
# 18737                               Captain Blood    X360        Action
# 18775                                  Disorder 6    X360  Visual Novel
# 18810                     Falling Skies: The Game    X360  Role-Playing
# 18813  Final Fantasy XI: The Vana'diel Collection    X360  Role-Playing
# 18818   Far East of Eden Ziria: Harukanaru Jipang    X360  Role-Playing
#
#                     publisher       developer  critic_score  total_sales  \
# ...

# %% [markdown]
# - Mais recomendável usar **query()** para filtro de dados

# %%
df[(df['developer']=='Rockstar North')]
# Out:
#                                                    title console      genre  \
# 0                                     Grand Theft Auto V     PS3     Action
# 1                                     Grand Theft Auto V     PS4     Action
# 2                            Grand Theft Auto: Vice City     PS2     Action
# 3                                     Grand Theft Auto V    X360     Action
# 16                                   Grand Theft Auto IV    X360     Action
# 19                                   Grand Theft Auto IV     PS3     Action
# 28                                    Grand Theft Auto V    XOne     Action
# 338         Grand Theft Auto: Episodes from Liberty City    X360  Adventure
# 357    Rockstar Games Double Pack: Grand Theft Auto I...      XB     Action
# 478         Grand Theft Auto: Episodes from Liberty City     PS3  Adventure
# 541                        Grand Theft Auto: San Andreas      XB     Action
# ...

# %% [markdown]
# - **value_counts():** Conta quantas vezes um elemento ocorre no Dataframe ou em um Series

# %%
df['genre'].value_counts()
# Out:
# genre
# Action              2825
# Sports              2581
# Misc                1988
# Adventure           1888
# Role-Playing        1483
# Shooter             1480
# Racing              1422
# Simulation          1116
# Platform             949
# Fighting             867
# Strategy             818
# Puzzle               719
# Action-Adventure     264
# Visual Novel         218
# Music                147
# MMO                   30
# Party                 29
# Education              4
# Board Game             3
# Sandbox                1
# Name: count, dtype: int64

# %% [markdown]
# ### Slicing
# > tô usando errado, não entendi isso
#
# > é para retornar a linha do meio do dataset

# %%
meio = len(df)//2
df.loc[meio:meio]
# Out:
#                                  title console   genre     publisher  \
# 9416  Dorabase 2: Nettou Ultra Stadium      DS  Sports  Namco Bandai
#
#                developer  critic_score  total_sales  release_year
# 9416  Bandai Namco Games           7.3         0.12        2009.0

# %%
meio = len(df)//2
df.iloc[meio:meio+1]
# Out:
#                                  title console   genre     publisher  \
# 9416  Dorabase 2: Nettou Ultra Stadium      DS  Sports  Namco Bandai
#
#                developer  critic_score  total_sales  release_year
# 9416  Bandai Namco Games           7.3         0.12        2009.0

# %% [markdown]
# ### Ordenação com sort_values()

# %%
df.sort_values(by=['release_year'], ascending=True)
# Out:
#                                                    title console  \
# 1531                                      Air-Sea Battle    2600
# 1101                                              Combat    2600
# 5834                                            Indy 500    2600
# 3855                                      Super Breakout    2600
# 6776                                        Breakaway IV    2600
# ...                                                  ...     ...
# 8859       The Legend of Heroes: Trails of Cold Steel IV     PS4
# 16211                                         Let It Die     PS4
# 18795                Aokana: Four Rhythm Across the Blue      NS
# 16238  Fujiko F. Fujio Characters: Great Assembly! Sl...     3DS
# 12955            Disaster Report 4 Plus: Summer Memories     PS4
#
#                   genre           publisher                developer  \
# 1531            Shooter               Atari                    Atari
# ...

# %% [markdown]
# ### Agrupamento com groupby()

# %%
df.groupby('genre')['critic_score'].sum() # somando os scores agrupando pelo gênero
df.groupby('genre')['critic_score'].min() # retornando os scores mínimos desse agrupamento
# Out:
# genre
# Action              1.0
# Action-Adventure    2.8
# Adventure           2.5
# Board Game          5.3
# Education           7.3
# Fighting            2.9
# MMO                 6.5
# Misc                2.0
# Music               6.5
# Party               4.0
# Platform            1.5
# Puzzle              3.5
# Racing              2.0
# Role-Playing        1.0
# Sandbox             9.2
# Shooter             1.7
# Simulation          1.5
# Sports              1.4
# Strategy            2.5
# Visual Novel        7.3
# Name: critic_score, dtype: float64

# %% [markdown]
# - **reset_index():** Cria um novo dataframe baseado no agrupamento e no método usado

# %%
df.groupby('genre')['critic_score'].sum().reset_index() # cria um novo dataframe baseado no agrupamento e no método usado
# Out:
#                genre  critic_score
# 0             Action       20182.4
# 1   Action-Adventure        1940.3
# 2          Adventure       13715.8
# 3         Board Game          19.9
# 4          Education          30.1
# 5           Fighting        6316.2
# 6                MMO         219.2
# 7               Misc       14402.1
# 8              Music        1081.8
# 9              Party         197.7
# 10          Platform        6802.2
# 11            Puzzle        5227.9
# 12            Racing       10328.7
# 13      Role-Playing       10866.3
# 14           Sandbox           9.2
# 15           Shooter       10759.0
# 16        Simulation        8070.6
# 17            Sports       18911.7
# 18          Strategy        5982.3
# 19      Visual Novel        1593.1

# %% [markdown]
# ### Gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=df, y='genre', order=df['genre'].value_counts().index)
plt.title('Distribuição da Variável Descrição')
plt.xlabel('Contagem')
plt.ylabel('Gênero')
plt.show()

# %% [markdown]
# - interativo com plotly

# %%
import plotly.express as px

counts_data = df['genre'].value_counts().reset_index()
counts_data.columns = ['genre', 'Contagem']

grafico = px.bar(
    counts_data,
    x='Contagem',
    y='genre',
    title="Contagem de ocorrências dos gêneros dos jogos mais vendidos",
    category_orders={'genre': counts_data['genre'].tolist()},
    text='Contagem'
)

grafico.update_traces(textposition='outside')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Análise de variáveis quantitativas
# > count: contagem
#
# > mean: média
#
# > std: desvio padrão
#
# > 25%: primeiro quartil
#
# > 50%: segundo quartil
#
# > 75%: terceiro quartil

# %%
critic_score = df["critic_score"].describe()
critic_score
# Out:
# count    18832.000000
# mean         7.256611
# std          0.678515
# min          1.000000
# 25%          7.300000
# 50%          7.300000
# 75%          7.300000
# max         10.000000
# Name: critic_score, dtype: float64

# %% [markdown]
# ### Histograma e Boxplot de uma das variáveis quantitativas do dataset

# %% [markdown]
# > Boxplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='critic_score')
plt.axvline(critic_score['50%'], color='red', linestyle='--', label=f'Mediana: {critic_score["50%"]:.2f}')
plt.title('Box Plot da Variável Nota da Crítica (critic_score) com Mediana Destacada')
plt.xlabel('Nota da crítica')
plt.legend()
plt.show()

# %% [markdown]
# > Histograma

# %%
import pandas as pd
import kagglehub
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar o DataFrame df, caso não esteja carregado
path = kagglehub.dataset_download("bhushandivekar/video-game-sales-and-industry-data-1980-2024") # aqui ele baixa uma pasta com os dados
df = pd.read_csv(path + "/Video_Games_Sales_Cleaned.csv")
bin_size=len(df["critic_score"].value_counts()) # Total de valores difeentes
plt.figure(figsize=(10, 6))
ax = sns.histplot(data=df, x='critic_score', bins='auto') # Changed stat to 'count' and adjusted bins
plt.title('Distribuição da Variável Nota da Crítica com Contagens')
plt.xlabel('critic_score')
plt.ylabel('Contagem') # Rótulo alterado para Contagem

# Add labels on top of bars
for p in ax.patches:
    # Get the height of the bar. It's the count.
    height = p.get_height()
    # If the height is 0, skip it to avoid clutter
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., # x-coordinate of text (center of bar)
                height, # y-coordinate of text (top of bar)
                f'{int(height)}', # text to display (integer count)
                ha='center', va='bottom', fontsize=8) # horizontal and vertical alignment
plt.show()
# Out:
# Using Colab cache for faster access to the 'video-game-sales-and-industry-data-1980-2024' dataset.

# %%
import plotly.express as px
grafico=px.histogram(df, x='critic_score', title='Distribuição da Variável Nota da Crítica',labels={'critic_score':'critic_score'},marginal="violin")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd

profile = ProfileReport(
    df,
    title="EDA - Dataset de Vendas de Jogos",
    explorative=True
)

# profile.to_file("relatorio_eda_vendas_jogos.html")

profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-05-12 18:34:11.901207&quot; name=date&gt;&lt;title&gt;EDA - Dataset de Vendas de Jogos&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
